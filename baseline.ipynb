# %%
import pandas as pd
import numpy as np
import datetime

from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('kickstarter.csv')
data.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
len(data)
# Out:
# 378661

# %%
# Start-up outcomes categories
print('Outcome: ', list(data['state'].unique()))
# Out:
# Outcome:  ['failed', 'canceled', 'successful', 'live', 'undefined', 'suspended']

# %%
live = np.where(data.state == 'live')[0]

print('The indeces: ', live)
# Out:
# The indeces:  [    40    183    458 ... 378429 378496 378512]

# %%
data.iloc[live]
# Out:
#                 ID                                               name  \
# 40      1000149007             Unschooling To University Book Project
# 183     1000761521                                             KILOS.
# 458     1002183790                               The Man in the Field
# 537     1002599057                                      Dear Atlantas
# 544     1002629894                                  Art Calendar 2018
# 627      100301082                             Feliz año nuevo, mamá.
# 641     1003104071                                 One GuitarMan Band
# 752     1003665581                              Durango Falls TV Show
# 783     1003819770                                       GrandLo Café
# 842      100411349            E Coin Mining and Rig-Building Workshop
# 894     1004434782  DIY BOXCAT by Rato Kim - The Vinyl Art Toy Pla...
# 990     1005020458                             Tiddly Trailer Bar Co.
# 1427    1007266579                               Pedal Whip Multitool
# 1502    1007700830                PHILE Magazine Issue No. 2 PRE-SALE
# 1595    1008176449          Twenty-Six: Poetic Affirmations for Women
# 1603     100822204  Freedom Ride Jacket | Revolutionizing Urban Cy...
# 1920    1009892892                                     MORE BIKE LIFE
# 2267    1011784198                      Through the Eyes of My Mother
# 2392    1012399283                               "The Woman in White"
# 2594     101336613                                      I am Thankful
# 2852    1014813411  YUMMA WEAR BY INTEGRESS INDUSTRIES INC. - ATHL...
# 2856     101483724                               The Advent Storybook
# 2892    1014982951        Freedom Through Art | Drawings That Inspire
# 2982    1015409774                      SpinBlock Table Tennis Center
# 3325    1017200721        Hacked at 17 - Teaching Teens Online Safety
# 3338    1017252588                   My Debut EP - "Shine!" - PHASE 1
# 3996    1020564977  AfterMarket Percussion Products, Inc. (AMPP, Inc)
# 4039    1020721729  Edensoles | Sole To Soul Comfort with Dynamic ...
# 4055    1020847392  Stop-A-Spill, The Coolest Way To Save Your Des...
# 4134    1021242831                                 Plume: the Omnibus
# ...            ...                                                ...
# 374880   980522602                                      Steve's Story
# 374904   980594622                         RESCUE MAC, IN10SE MINUTES
# 374927   980694521                       Sexywear by Anna Elizabeth I
# 375100   981610951     “Crocochain” - Skeleton Hand Crafted Multitool
# 375195   982145967                                  Agnes' Front Lawn
# 375244   982368556              Toddlr - Creating lasting friendships
# 375284    98257013              The "alley" Reversible Solar BackPack
# 375395   983080290                                         Art in 365
# 375470   983530643  Pop-up store in Paris for 2018 spring collection.
# 375607   984297189                   Major Arcana Tarot by A MIYAKO M
# 375660   984590245                                     Arrieros Somos
# 375883   985779919                    Stop harassment. Be the change.
# 376125   987063934  Leonardo da Vinci -Notebook Illustrations (Vol...
# 376378   988360360                   Molly Marrow- Debut EP 'Lead Me'
# 376479   988819801  Gaz Bailey,s - Debut Album "Folk It!" With you...
# 376594   989429327    ZOMBIE BINGO - Short student comedy-horror film
# 377042   991818171                                  Monsters and Kids
# 377058   991937746                                       Find Me Game
# 377108   992131825                                     THE GLOBALISTS
# 377177   992522969                          Personalized Crayon Banks
# 377058            426.00       20000.00
# 377108           1871.00        2800.00
# 377177              1.11       50000.00
# 377224            450.00        7500.00
# 377265           5569.00        4089.88
# 377325              0.00        6500.00
# 377375          23397.00       15000.00
# 377419            679.42       52747.60
# 377942            982.06        1363.98
# 378145           3500.00        5800.00
# 378429           1080.00        1500.00
# 378496              0.00       15490.27
# 378512            162.94       30313.01
#
# [2799 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
# ID                  378661 non-null int64
# name                378657 non-null object
# category            378661 non-null object
# main_category       378661 non-null object
# currency            378661 non-null object
# deadline            378661 non-null object
# goal                378661 non-null float64
# launched            378661 non-null object
# pledged             378661 non-null float64
# state               378661 non-null object
# backers             378661 non-null int64
# country             378661 non-null object
# usd pledged         374864 non-null float64
# usd_pledged_real    378661 non-null float64
# usd_goal_real       378661 non-null float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 43.3+ MB

# %%
# Ati dropping the live projects...
data = data.query('state != "live"')

len(data)
# Out:
# 375862

# %%
# Now all the indeces with live projects were eliminated
live = np.where(data.state == 'live')[0]

print('The indeces: ', live)
# Out:
# The indeces:  []

# %%
data.loc[live]
# Out:
# Empty DataFrame
# Columns: [ID, name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd pledged, usd_pledged_real, usd_goal_real]
# Index: []

# %%
# Adding a new column for the outcome
# Assigning 'successful' == 1 and others == 0

data = data.assign(outcome=(data['state'] == 'successful').astype(int))

data.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real  outcome
# 0               0.0        1533.95        0
# 1            2421.0       30000.00        0
# 2             220.0       45000.00        0
# 3               1.0        5000.00        0
# 4            1283.0       19500.00        0

# %%
data.launched.dtype
# Out:
# dtype('O')

# %%
data[['launched']].head()
# Out:
#               launched
# 0  2015-08-11 12:12:28
# 1  2017-09-02 04:43:57
# 2  2013-01-12 00:20:50
# 3  2012-03-17 03:24:11
# 4  2015-07-04 08:35:03

# %%
# COnverting the launched col into datetime
data.launched = pd.to_datetime(data.launched, infer_datetime_format=True)

data.launched.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.launched.head()
# Out:
# 0   2015-08-11 12:12:28
# 1   2017-09-02 04:43:57
# 2   2013-01-12 00:20:50
# 3   2012-03-17 03:24:11
# 4   2015-07-04 08:35:03
# Name: launched, dtype: datetime64[ns]

# %%
# After converting dates
# Creating new cols for day, hour, month and year
# Assigning the appropriate values from the launched col <timestamp>

data = data.assign(hour=data.launched.dt.hour,
                  day=data.launched.dt.day, 
                  month=data.launched.dt.month,
                  year=data.launched.dt.year)

data.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#              launched  pledged     state  backers country  usd pledged  \
# 0 2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1 2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2 2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3 2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4 2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real  outcome  hour  day  month  year
# 0               0.0        1533.95        0    12   11      8  2015
# 1            2421.0       30000.00        0     4    2      9  2017
# 2             220.0       45000.00        0     0   12      1  2013
# 3               1.0        5000.00        0     3   17      3  2012
# 4            1283.0       19500.00        0     8    4      7  2015

# %%
cats = ['category', 'currency', 'country']

# %%
encoder = LabelEncoder()

# %%
enc_cats = data[cats].apply(encoder.fit_transform)

# %%
enc_cats.head()
# Out:
#    category  currency  country
# 0       108         5        9
# 1        93        13       22
# 2        93        13       22
# 3        90        13       22
# 4        55        13       22

# %%
X = data[['goal', 'hour', 'day', 'month', 'year', 'outcome']].join(enc_cats)
X.head()
# Out:
#       goal  hour  day  month  year  outcome  category  currency  country
# 0   1000.0    12   11      8  2015        0       108         5        9
# 1  30000.0     4    2      9  2017        0        93        13       22
# 2  45000.0     0   12      1  2013        0        93        13       22
# 3   5000.0     3   17      3  2012        0        90        13       22
# 4  19500.0     8    4      7  2015        0        55        13       22

# %%
# Creating training, validation and test sets

# %%
X.shape
# Out:
# (375862, 9)

# %%
valid_fraction = 0.1

valid_size = int(len(X) * valid_fraction)

valid_size
# Out:
# 37586

# %%
X.shape
# Out:
# (375862, 9)

# %%
train = X[:-2* valid_size]

train.shape
# Out:
# (300690, 9)

# %%
valid = X[-2*valid_size:-valid_size]
valid.shape
# Out:
# (37586, 9)

# %%
test = X[-valid_size:]
test.shape
# Out:
# (37586, 9)

# %%
# Now train a model
import lightgbm as lgb
#using a LightGBM model. This is a tree-based model that typically provides the 
# Best performance, even compared to XGBoost. It's also relatively fast to train.

# %%
feature_cols = train.columns.drop('outcome')
feature_cols
# Out:
# Index(['goal', 'hour', 'day', 'month', 'year', 'category', 'currency',
#        'country'],
#       dtype='object')

# %%
dtrain = lgb.Dataset(train[feature_cols], label=train['outcome'])

dvalid = lgb.Dataset(valid[feature_cols], label=valid['outcome'])

# %%
param = {'num_leaves': 64, 'objective': 'binary'}
param['metric'] = 'auc'
num_round = 1000

bst = lgb.train(param, dtrain, num_round, valid_sets=[dvalid], early_stopping_rounds=5)
# Out:
# [LightGBM] [Info] Number of positive: 107340, number of negative: 193350
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012047 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 528
# [LightGBM] [Info] Number of data points in the train set: 300690, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.356979 -> initscore=-0.588501
# [LightGBM] [Info] Start training from score -0.588501
# [1]	valid_0's auc: 0.694192
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's auc: 0.697026
# [3]	valid_0's auc: 0.70002
# [4]	valid_0's auc: 0.701645
# [5]	valid_0's auc: 0.70601
# [6]	valid_0's auc: 0.707926
# [7]	valid_0's auc: 0.70945
# [8]	valid_0's auc: 0.710437
# [9]	valid_0's auc: 0.712047
# [10]	valid_0's auc: 0.713417
# [11]	valid_0's auc: 0.714648
# [12]	valid_0's auc: 0.715791
# [13]	valid_0's auc: 0.717431
# [14]	valid_0's auc: 0.718216
# [15]	valid_0's auc: 0.719381
# [16]	valid_0's auc: 0.720884
# [17]	valid_0's auc: 0.721617
# [18]	valid_0's auc: 0.722788
# [19]	valid_0's auc: 0.723305
# [20]	valid_0's auc: 0.724826
# [21]	valid_0's auc: 0.725596
# [22]	valid_0's auc: 0.727436
# [23]	valid_0's auc: 0.72788
# [24]	valid_0's auc: 0.728838
# [25]	valid_0's auc: 0.729249
# [26]	valid_0's auc: 0.730276
# [27]	valid_0's auc: 0.730651
# [28]	valid_0's auc: 0.731264
# [29]	valid_0's auc: 0.731584
# [30]	valid_0's auc: 0.732643
# [31]	valid_0's auc: 0.733118
# [32]	valid_0's auc: 0.733422
# [33]	valid_0's auc: 0.734007
# [34]	valid_0's auc: 0.734475
# [35]	valid_0's auc: 0.734652
# [36]	valid_0's auc: 0.73488
# [37]	valid_0's auc: 0.735944
# [38]	valid_0's auc: 0.73617
# [39]	valid_0's auc: 0.736498
# [40]	valid_0's auc: 0.736767
# [41]	valid_0's auc: 0.737663
# [42]	valid_0's auc: 0.737783
# [43]	valid_0's auc: 0.73798
# [44]	valid_0's auc: 0.738213
# [45]	valid_0's auc: 0.738784
# [46]	valid_0's auc: 0.738881
# [47]	valid_0's auc: 0.739012
# [48]	valid_0's auc: 0.739203
# [49]	valid_0's auc: 0.739353
# [50]	valid_0's auc: 0.739844
# [51]	valid_0's auc: 0.739929
# [52]	valid_0's auc: 0.74008
# [53]	valid_0's auc: 0.740276
# [54]	valid_0's auc: 0.740519
# [55]	valid_0's auc: 0.740655
# [56]	valid_0's auc: 0.740712
# [57]	valid_0's auc: 0.741008
# [58]	valid_0's auc: 0.74109
# [59]	valid_0's auc: 0.741133
# [60]	valid_0's auc: 0.741264
# [61]	valid_0's auc: 0.741467
# [62]	valid_0's auc: 0.741628
# [63]	valid_0's auc: 0.741912
# [64]	valid_0's auc: 0.742196
# [65]	valid_0's auc: 0.742252
# [66]	valid_0's auc: 0.742332
# [67]	valid_0's auc: 0.742413
# [68]	valid_0's auc: 0.742516
# [69]	valid_0's auc: 0.742732
# [70]	valid_0's auc: 0.742774
# [71]	valid_0's auc: 0.742838
# [72]	valid_0's auc: 0.743004
# [73]	valid_0's auc: 0.743035
# [74]	valid_0's auc: 0.74308
# [75]	valid_0's auc: 0.743136
# [76]	valid_0's auc: 0.743692
# [77]	valid_0's auc: 0.743737
# [78]	valid_0's auc: 0.74382
# [79]	valid_0's auc: 0.743885
# [80]	valid_0's auc: 0.743901
# [81]	valid_0's auc: 0.744103
# [82]	valid_0's auc: 0.744096
# [83]	valid_0's auc: 0.744116
# [84]	valid_0's auc: 0.744169
# [85]	valid_0's auc: 0.744238
# [86]	valid_0's auc: 0.744322
# [87]	valid_0's auc: 0.744317
# [88]	valid_0's auc: 0.744377
# [89]	valid_0's auc: 0.744429
# [90]	valid_0's auc: 0.74449
# [91]	valid_0's auc: 0.744508
# [92]	valid_0's auc: 0.744506
# [93]	valid_0's auc: 0.744536
# [94]	valid_0's auc: 0.744573
# [95]	valid_0's auc: 0.744585
# [96]	valid_0's auc: 0.744584
# [97]	valid_0's auc: 0.744695
# [98]	valid_0's auc: 0.744693
# [99]	valid_0's auc: 0.744694
# [100]	valid_0's auc: 0.744673
# [101]	valid_0's auc: 0.744673
# [102]	valid_0's auc: 0.744711
# [103]	valid_0's auc: 0.744707
# [104]	valid_0's auc: 0.744769
# [105]	valid_0's auc: 0.744816
# [106]	valid_0's auc: 0.744817
# [107]	valid_0's auc: 0.744803
# [108]	valid_0's auc: 0.744816
# [109]	valid_0's auc: 0.744857
# [110]	valid_0's auc: 0.74515
# [111]	valid_0's auc: 0.745133
# [112]	valid_0's auc: 0.7451
# [113]	valid_0's auc: 0.745123
# [114]	valid_0's auc: 0.745126
# [115]	valid_0's auc: 0.745099
# Early stopping, best iteration is:
# [110]	valid_0's auc: 0.74515

# %%
# Make predictions and evaluate the model
from sklearn import metrics

# %%
predictions = bst.predict(test[feature_cols])

# %%
score = metrics.roc_auc_score(test['outcome'], predictions)

print(f'Test AUC score: {score}')
# Out:
# Test AUC score: 0.7453069666284735
